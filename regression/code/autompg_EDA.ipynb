# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data=data[data.horsepower!='?']
data=data.astype({'horsepower':'int64'})

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
sns.countplot(x='cylinders', data=data)

# %%
sns.countplot(x='origin', data=data)

# %%
sns.distplot(data['mpg'])

# %%
new = data.drop(columns = ['cylinders','origin','car name'])
new
# Out:
#       mpg  displacement  horsepower  weight  acceleration  model year
# 0    18.0         307.0         130    3504          12.0          70
# 1    15.0         350.0         165    3693          11.5          70
# 2    18.0         318.0         150    3436          11.0          70
# 3    16.0         304.0         150    3433          12.0          70
# 4    17.0         302.0         140    3449          10.5          70
# ..    ...           ...         ...     ...           ...         ...
# 393  27.0         140.0          86    2790          15.6          82
# 394  44.0          97.0          52    2130          24.6          82
# 395  32.0         135.0          84    2295          11.6          82
# 396  28.0         120.0          79    2625          18.6          82
# 397  31.0         119.0          82    2720          19.4          82
#
# [392 rows x 6 columns]

# %%
data2 = data.drop(columns = ['car name'])

# %%
data2
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
new2 = data.drop(columns = ['cylinders','origin','car name','mpg'])
new2
# Out:
#      displacement  horsepower  weight  acceleration  model year
# 0           307.0         130    3504          12.0          70
# 1           350.0         165    3693          11.5          70
# 2           318.0         150    3436          11.0          70
# 3           304.0         150    3433          12.0          70
# 4           302.0         140    3449          10.5          70
# ..            ...         ...     ...           ...         ...
# 393         140.0          86    2790          15.6          82
# 394          97.0          52    2130          24.6          82
# 395         135.0          84    2295          11.6          82
# 396         120.0          79    2625          18.6          82
# 397         119.0          82    2720          19.4          82
#
# [392 rows x 5 columns]

# %%
new2.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018CB18DE430>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data = new.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
# 그림 사이즈 지정
fig, ax = plt.subplots( figsize=(10,7) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(new.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(new.corr(), 
            cmap = 'Blues', 
            fmt = '.2f',
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
import statsmodels as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

X1 = sm.tools.add_constant(new)
series1 = pd.Series([variance_inflation_factor(X1.values,i) for i in range(X1.shape[1])],index=X1.columns)
print('Series before feature selection: \n\n{}\n'.format(series1))
# Out:
# Series before feature selection:
#
# const           747.089537
# mpg               5.229210
# displacement     10.830415
# horsepower        9.299039
# weight           13.506058
# acceleration      2.624391
# model year        1.907007
# dtype: float64

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(new.values, i) for i in range(new.shape[1])]
vif["features"] = new.columns
vif
# Out:
#    VIF Factor      features
# 0   51.095204           mpg
# 1   48.281343  displacement
# 2   60.689430    horsepower
# 3  170.211123        weight
# 4   69.366612  acceleration
# 5  268.579783    model year

# %%
X2 = sm.tools.add_constant(data2)
X2
# Out:
#      const   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0      1.0  18.0          8         307.0         130    3504          12.0
# 1      1.0  15.0          8         350.0         165    3693          11.5
# 2      1.0  18.0          8         318.0         150    3436          11.0
# 3      1.0  16.0          8         304.0         150    3433          12.0
# 4      1.0  17.0          8         302.0         140    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    1.0  27.0          4         140.0          86    2790          15.6
# 394    1.0  44.0          4          97.0          52    2130          24.6
# 395    1.0  32.0          4         135.0          84    2295          11.6
# 396    1.0  28.0          4         120.0          79    2625          18.6
# 397    1.0  31.0          4         119.0          82    2720          19.4
#
#      model year  origin
# 0            70       1
# ...

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])]
vif["features"] = X2.columns
vif
# Out:
#    VIF Factor      features
# 0  790.888714         const
# 1    5.601553           mpg
# 2   10.802663     cylinders
# 3   22.235364  displacement
# 4    9.982839    horsepower
# 5   13.611870        weight
# 6    2.630350  acceleration
# 7    1.948277    model year
# 8    1.893736        origin
